# %% [markdown]
# # TFIDF RUN

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
from collections import defaultdict
import re

# %%
_DEVANAGARI_PATTERN = re.compile(r'[\u0900-\u0963\u0966-\u097F]+')

with open("data/stopwords.txt", "r", encoding="utf-8") as f:
    _STOPWORDS = set(line.strip() for line in f)

def tokenize(text):
    # extract words but ignore । and ॥
    words = _DEVANAGARI_PATTERN.findall(text)
    normalized = [word.replace("\u0940", "\u093F").replace("\u0942", "\u0941") for word in words]
    return [word for word in normalized if word not in _STOPWORDS]

def compute_tfidf(corpus):
    vectorizer = TfidfVectorizer( tokenizer=tokenize, token_pattern=None, use_idf=True, sublinear_tf=True)

    tfidf_matrix = vectorizer.fit_transform(corpus["text"].tolist())

    return tfidf_matrix, vectorizer

def search(query, tfidf_matrix, vectorizer, top_k=10):
    query_vector = vectorizer.transform([query])
    similarities = cosine_similarity(query_vector, tfidf_matrix)[0]
    top_indices = similarities.argsort()[-top_k:][::-1]
    return [(idx, similarities[idx]) for idx in top_indices]

# %%
TOP_K = 10
RUN_FILE = "data/tfidf_run.json"
QUERIES_FILE = "data/queries.csv"
CORPUS_FILE = 'data/corpus_trec.csv'

# 1. Load Data and Compute TF-IDF
corpus = pd.read_csv(CORPUS_FILE)

# The DocID column must be correctly named in your corpus.csv
doc_ids = corpus['DocID'].tolist() 

tfidf_matrix, vectorizer = compute_tfidf(corpus)

# %%
# 2. Load Queries
queries = pd.read_csv(QUERIES_FILE)
results = defaultdict()
for qid, query in queries.iterrows():
    results[query['QueryID']] = search(query['Query'], tfidf_matrix, vectorizer, TOP_K)

# %%
# converting indexes to docids
doc_ids = corpus['DocID'].tolist()

for query in results:
    results[query] = [doc_ids[r[0]] for r in results[query]]

print(results)
# Out:
# defaultdict(None, {'Q0001': ['NWA02278', 'NWA73714', 'NWA02057', 'NWA07971', 'NWA04154', 'NWA02161', 'NWA06069', 'NWA06955', 'NWA06671', 'NWA35375'], 'Q0002': ['NWA42460', 'NWA41512', 'NWA13395', 'NWA41235', 'NWA43004', 'NWA12906', 'NWA12293', 'NWA40732', 'NWA13220', 'NWA42900'], 'Q0003': ['NWA78084', 'NWA70055', 'NWA78312', 'NWA74001', 'NWA07085', 'NWA12419', 'NWA07355', 'NWA78410', 'NWA07325', 'NWA73779'], 'Q0004': ['NWA13817', 'NWA74044', 'NWA10048', 'NWA77203', 'NWA77194', 'NWA29710', 'NWA74082', 'NWA01957', 'NWA09784', 'NWA07474'], 'Q0005': ['NWA31379', 'NWA34729', 'NWA27768', 'NWA27785', 'NWA27730', 'NWA27757', 'NWA27763', 'NWA31403', 'NWA27815', 'NWA27729'], 'Q0006': ['NWA13355', 'NWA29710', 'NWA11583', 'NWA42986', 'NWA39866', 'NWA39933', 'NWA41091', 'NWA74788', 'NWA11425', 'NWA12165'], 'Q0007': ['NWA53394', 'NWA78312', 'NWA74001', 'NWA78410', 'NWA73779', 'NWA73777', 'NWA73776', 'NWA73836', 'NWA73778', 'NWA07355'], 'Q0008': ['NWA28562', 'NWA74696', 'NWA02358', 'NWA75540', 'NWA75539', 'NWA75538', 'NWA75537', 'NWA75536', 'NWA75535', 'NWA75534'], 'Q0009': ['NWA19086', 'NWA00162', 'NWA76133', 'NWA00478', 'NWA37695', 'NWA04791', 'NWA04434', 'NWA01100', 'NWA76992', 'NWA65858'], 'Q0010': ['NWA31550', 'NWA26005', 'NWA24208', 'NWA71523', 'NWA34233', 'NWA27062', 'NWA15368', 'NWA27196', 'NWA74002', 'NWA23419'], 'Q0011': ['NWA29710', 'NWA78483', 'NWA42350', 'NWA58204', 'NWA02885', 'NWA78572', 'NWA77388', 'NWA02777', 'NWA04645', 'NWA00908'], 'Q0012': ['NWA52035', 'NWA52033', 'NWA52229', 'NWA52283', 'NWA52034', 'NWA52233', 'NWA78312', 'NWA50693', 'NWA60626', 'NWA50701'], 'Q0013': ['NWA55785', 'NWA46433', 'NWA73743', 'NWA06446', 'NWA38482', 'NWA11632', 'NWA19025', 'NWA21958', 'NWA07865', 'NWA59756'], 'Q0014': ['NWA36792', 'NWA38074', 'NWA71523', 'NWA36201', 'NWA36158', 'NWA35690', 'NWA35701', 'NWA35645', 'NWA35826', 'NWA37754'], 'Q0015': ['NWA48071', 'NWA38349', 'NWA36463', 'NWA49333', 'NWA50888', 'NWA31163', 'NWA52894', 'NWA52971', 'NWA34907', 'NWA35282'], 'Q0016': ['NWA77625', 'NWA56748', 'NWA77697', 'NWA65037', 'NWA72443', 'NWA77437', 'NWA78016', 'NWA77864', 'NWA76042', 'NWA64043'], 'Q0017': ['NWA58694', 'NWA77503', 'NWA77507', 'NWA78034', 'NWA66992', 'NWA67946', 'NWA46830', 'NWA29344', 'NWA46814', 'NWA46841'], 'Q0018': ['NWA11437', 'NWA41512', 'NWA13395', 'NWA41235', 'NWA43004', 'NWA12906', 'NWA12293', 'NWA40732', 'NWA13220', 'NWA42900'], 'Q0019': ['NWA73627', 'NWA75836', 'NWA01201', 'NWA63822', 'NWA08647', 'NWA74483', 'NWA03366', 'NWA12776', 'NWA05060', 'NWA03165'], 'Q0020': ['NWA76101', 'NWA76102', 'NWA76103', 'NWA76100', 'NWA76099', 'NWA76096', 'NWA73813', 'NWA75995', 'NWA75996', 'NWA75997'], 'Q0021': ['NWA78655', 'NWA68932', 'NWA59954', 'NWA29710', 'NWA77503', 'NWA75720', 'NWA77507', 'NWA75243', 'NWA78034', 'NWA78335'], 'Q0022': ['NWA58401', 'NWA78312', 'NWA74001', 'NWA78410', 'NWA73779', 'NWA73777', 'NWA73776', 'NWA73836', 'NWA73778', 'NWA07355'], 'Q0023': ['NWA50200', 'NWA46433', 'NWA73743', 'NWA06446', 'NWA38482', 'NWA11632', 'NWA19025', 'NWA21958', 'NWA07865', 'NWA40636'], 'Q0024': ['NWA38685', 'NWA38686', 'NWA38689', 'NWA38681', 'NWA38684', 'NWA38697', 'NWA38682', 'NWA38679', 'NWA38675', 'NWA38680'], 'Q0025': ['NWA54564', 'NWA55791', 'NWA54562', 'NWA54563', 'NWA55790', 'NWA55789', 'NWA29710', 'NWA78312', 'NWA74001', 'NWA42350'], 'Q0026': ['NWA03479', 'NWA05579', 'NWA03614', 'NWA00382', 'NWA29710', 'NWA07734', 'NWA04138', 'NWA02885', 'NWA07943', 'NWA07590'], 'Q0027': ['NWA08574', 'NWA68932', 'NWA59954', 'NWA29710', 'NWA77503', 'NWA75720', 'NWA77507', 'NWA75243', 'NWA78034', 'NWA78335'], 'Q0028': ['NWA74914', 'NWA74207', 'NWA74260', 'NWA74240', 'NWA74241', 'NWA74231', 'NWA74234', 'NWA74242', 'NWA74243', 'NWA74233'], 'Q0029': ['NWA29710', 'NWA42350', 'NWA02885', 'NWA02777', 'NWA07676', 'NWA74532', 'NWA07734', 'NWA08032', 'NWA74871', 'NWA07865'], 'Q0030': ['NWA44476', 'NWA44992', 'NWA51583', 'NWA46783', 'NWA75571', 'NWA56626', 'NWA44914', 'NWA44937', 'NWA44948', 'NWA44959'], 'Q0031': ['NWA24726', 'NWA07590', 'NWA07201', 'NWA0 ...

# %%
# saving the run in a json file
import json

outputfile = "data/tfidf.json"

with open(outputfile, 'w', encoding='utf-8') as f:
    json.dump(results,
              f,
              indent=4,
              ensure_ascii=False
             )

# %% [markdown]
# # Muril Run

# %%
import pandas as pd
import torch
import torch.nn.functional as F
from collections import defaultdict
from transformers import AutoTokenizer, AutoModel

# %%
TOP_K = 10
QUERIES_FILE = "data/queries.csv"
RUN_FILE = "data/muril.json"
CORPUS_FILE = 'data/corpus_trec.csv'
MODEL_NAME = "sundeepdwd/muril-mlm-newa-finetuned"

# %%
def get_mean_pooling(model_output, attention_mask):
    """Mean pooling to get a single vector representation for the sequence."""
    token_embeddings = model_output.last_hidden_state
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    return sum_embeddings / sum_mask

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# 1. Load Model and Data
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME)

model.to(device)

corpus = pd.read_csv(CORPUS_FILE)
doc_ids = corpus['DocID'].tolist() 
doc_texts = corpus['text'].tolist()

# NOTE: This step is memory intensive. For 80,000+ docs, pre-calculate embeddings once.
print("Computing document embeddings (can take time for large corpus)...")
doc_embeddings = []

# Batch processing is recommended for 80k+ documents, but for simplicity:
for text in doc_texts:
    tokens = tokenizer(text, return_tensors='pt', truncation=True, padding=True)
    tokens.to(device)
    with torch.no_grad():
        output = model(**tokens)
    doc_embeddings.append(get_mean_pooling(output, tokens['attention_mask']))
    
all_doc_embeddings = torch.cat(doc_embeddings)

# 2. Load Queries
queries = pd.read_csv(QUERIES_FILE)
results = defaultdict()
for idx, query in queries.iterrows():
    qid = query['QueryID']
    title = query['Query'] # Use the title as the query text

    # 4. Compute Query Embedding
    query_tokens = tokenizer(title, return_tensors='pt', truncation=True, padding=True)
    query_tokens.to(device)
    with torch.no_grad():
        query_output = model(**query_tokens)
    query_embedding = get_mean_pooling(query_output, query_tokens['attention_mask'])
    
    # 5. Calculate Cosine Similarity
    # Compare the query embedding to all document embeddings
    # The result is a 1D tensor of scores
    scores = F.cosine_similarity(query_embedding, all_doc_embeddings)
    
    # 6. Sort and Select Top K
    top_scores, top_indices = torch.topk(scores, k=min(TOP_K, len(scores)))
    
    # Retrieve the corresponding DocIDs
    top_doc_ids = [doc_ids[i.item()] for i in top_indices]
    
    # Save to dick
    results[qid] = top_doc_ids
    print(f"Processed Query {qid} with {len(top_doc_ids)} results.")
# Out:
# Using device: cuda
# Some weights of BertModel were not initialized from the model checkpoint at sundeepdwd/muril-mlm-newa-finetuned and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Computing document embeddings (can take time for large corpus)...
# Processed Query Q0001 with 10 results.
# Processed Query Q0002 with 10 results.
# Processed Query Q0003 with 10 results.
# Processed Query Q0004 with 10 results.
# Processed Query Q0005 with 10 results.
# Processed Query Q0006 with 10 results.
# Processed Query Q0007 with 10 results.
# Processed Query Q0008 with 10 results.
# Processed Query Q0009 with 10 results.
# Processed Query Q0010 with 10 results.
# Processed Query Q0011 with 10 results.
# Processed Query Q0012 with 10 results.
# Processed Query Q0013 with 10 results.
# Processed Query Q0014 with 10 results.
# Processed Query Q0015 with 10 results.
# Processed Query Q0016 with 10 results.
# Processed Query Q0017 with 10 results.
# Processed Query Q0018 with 10 results.
# Processed Query Q0019 with 10 results.
# Processed Query Q0020 with 10 results.
# Processed Query Q0021 with 10 results.
# Processed Query Q0022 with 10 results.
# Processed Query Q0023 with 10 results.
# Processed Query Q0024 with 10 results.
# Processed Query Q0025 with 10 results.
# Processed Query Q0026 with 10 results.
# Processed Query Q0027 with 10 results.
# Processed Query Q0028 with 10 results.
# Processed Query Q0029 with 10 results.
# Processed Query Q0030 with 10 results.
# Processed Query Q0031 with 10 results.
# Processed Query Q0032 with 10 results.
# Processed Query Q0033 with 10 results.
# Processed Query Q0034 with 10 results.
# Processed Query Q0035 with 10 results.
# Processed Query Q0036 with 10 results.
# Processed Query Q0037 with 10 results.
# Processed Query Q0038 with 10 results.
# Processed Query Q0039 with 10 results.
# Processed Query Q0040 with 10 results.
# Processed Query Q0041 with 10 results.
# Processed Query Q0042 with 10 results.
# Processed Query Q0043 with 10 results.
# Processed Query Q0044 with 10 results.
# Processed Query Q0045 with 10 results.
# Processed Query Q0046 with 10 results.
# Processed Query Q0047 with 10 results.
# Processed Query Q0048 with 10 results.
# Processed Query Q0049 with 10 results.
# Processed Query Q0050 with 10 results.
# Processed Query Q0051 with 10 results.
# Processed Query Q0052 with 10 results.
# Processed Query Q0053 with 10 results.
# Processed Query Q0054 with 10 results.
# Processed Query Q0055 with 10 results.
# Processed Query Q0056 with 10 results.
# Processed Query Q0057 with 10 results.
# Processed Query Q0058 with 10 results.
# Processed Query Q0059 with 10 results.
# Processed Query Q0060 with 10 results.
# Processed Query Q0061 with 10 results.
# Processed Query Q0062 with 10 results.
# Processed Query Q0063 with 10 results.
# Processed Query Q0064 with 10 results.
# Processed Query Q0065 with 10 results.
# Processed Query Q0066 with 10 results.
# Processed Query Q0067 with 10 results.
# Processed Query Q0068 with 10 results.
# Processed Query Q0069 with 10 results.
# Processed Query Q0070 with 10 results.
# Processed Query Q0071 with 10 results.
# Processed Query Q0072 with 10 results.
# Processed Query Q0073 with 10 results.
# Processed Query Q0074 with 10 results.
# Processed Query Q0075 with 10 results.
# Processed Query Q0076 with 10 results.
# Processed Query Q0077 with 10 results.
# Processed Query Q0078 with 10 results.
# Processed Query Q0079 with 10 results.
# Processed Query Q0080 with 10 results.
# Processed Query Q0081 with 10 results.
# Processed Query Q0082 with 10 results.
# Processed Query Q0083 with 10 results.
# Processed Query Q0084 with 10 results.
# Processed Query Q0085 with 10 results.
# Processed Query Q0086 with 10 results.
# Processed Query Q0087 with 10 results.
# Processed Query Q0088 with 10 results.
# Processed Query Q0089 with 10 results.
# Processed Query Q0090 with 10 results.
# Processed Query Q0091 with 10 results.
# Processed Query Q0092 with 10 results.
# Processed Query Q0093 with 10 results.
# Processed Query Q0094 with 10 results.
# Processed Query Q0095 with 10 results.
# Processed Query Q0096 with 10 results.
# Processed Query Q0097 with 10 results.
# Processed Query Q0098 with 10 results.
# Processed Query Q0099 with 10 results.
# Processed Query Q0100 with 10 results.
# Processed Query Q0101 with 10 results.
# Processed Query Q0102 with 10 results.
# Processed Query Q0103 with 10 results.
# Processed Query Q0104 with 10 results.
# Processed Query Q0105 with 10 results.
# Processed Query Q0106 with 10 results.
# Processed Query Q0107 with 10 results.
# Processed Query Q0108 with 10 results.
# Processed Query Q0109 with 10 results.
# Processed Query Q0110 with 10 results.
# Processed Query Q0111 with 10 results.
# Processed Query Q0112 with 10 results.
# Processed Query Q0113 with 10 results.
# Processed Query Q0114 with 10 results.
# Processed Query Q0115 with 10 results.
# Processed Query Q0116 with 10 results.
# Processed Query Q0117 with 10 results.
# Processed Query Q0118 with 10 results.
# Processed Query Q0119 with 10 results.
# Processed Query Q0120 with 10 results.
# Processed Query Q0121 with 10 results.
# Processed Query Q0122 with 10 results.
# Processed Query Q0123 with 10 results.
# Processed Query Q0124 with 10 results.
# Processed Query Q0125 with 10 results.
# Processed Query Q0126 with 10 results.
# Processed Query Q0127 with 10 results.
# Processed Query Q0128 with 10 results.
# Processed Query Q0129 with 10 results.
# Processed Query Q0130 with 10 results.
# Processed Query Q0131 with 10 results.
# Processed Query Q0132 with 10 results.
# Processed Query Q0133 with 10 results.
# Processed Query Q0134 with 10 results.
# Processed Query Q0135 with 10 results.
# Processed Query Q0136 with 10 results.
# Processed Query Q0137 with 10 results.
# Processed Query Q0138 with 10 results.
# Processed Query Q0139 with 10 results.
# Processed Query Q0140 with 10 results.
# Processed Query Q0141 with 10 results.
# Processed Query Q0142 with 10 results.
# Processed Query Q0143 with 10 results.
# Processed Query Q0144 with 10 results.
# Processed Query Q0145 with 10 results.
# Processed Query Q0146 with 10 results.
# Processed Query Q0147 with 10 results.
# Processed Query Q0148 with 10 results.
# Processed Query Q0149 with 10 results.
# Processed Query Q0150 with 10 results.
# Processed Query Q0151 with 10 results.
# Processed Query Q0152 with 10 results.
# Processed Query Q0153 with 10 results.
# Processed Query Q0154 with 10 results.
# Processed Query Q0155 with 10 results.
# Processed Query Q0156 with 10 results.
# Processed Query Q0157 with 10 results.
# Processed Query Q0158 with 10 results.
# Processed Query Q0159 with 10 results.
# Processed Query Q0160 with 10 results.
# Processed Query Q0161 with 10 results.
# Processed Query Q0162 with 10 results.
# Processed Query Q0163 with 10 results.
# Processed Query Q0164 with 10 results.
# Processed Query Q0165 with 10 results.
# Processed Query Q0166 with 10 results.
# Processed Query Q0167 with 10 results.
# Processed Query Q0168 with 10 results.
# Processed Query Q0169 with 10 results.
# Processed Query Q0170 with 10 results.
# Processed Query Q0171 with 10 results.
# Processed Query Q0172 with 10 results.
# Processed Query Q0173 with 10 results.
# Processed Query Q0174 with 10 results.
# Processed Query Q0175 with 10 results.
# Processed Query Q0176 with 10 results.
# Processed Query Q0177 with 10 results.
# Processed Query Q0178 with 10 results.
# Processed Query Q0179 with 10 results.
# Processed Query Q0180 with 10 results.
# Processed Query Q0181 with 10 results.
# Processed Query Q0182 with 10 results.
# Processed Query Q0183 with 10 results.
# Processed Query Q0184 with 10 results.
# Processed Query Q0185 with 10 results.
# Processed Query Q0186 with 10 results.
# Processed Query Q0187 with 10 results.
# Processed Query Q0188 with 10 results.
# Processed Query Q0189 with 10 results.
# Processed Query Q0190 with 10 results.
# Processed Query Q0191 with 10 results.
# Processed Query Q0192 with 10 results.
# Processed Query Q0193 with 10 results.
# Processed Query Q0194 with 10 results.
# Processed Query Q0195 with 10 results.
# Processed Query Q0196 with 10 results.
# Processed Query Q0197 with 10 results.
# Processed Query Q0198 with 10 results.
# Processed Query Q0199 with 10 results.
# Processed Query Q0200 with 10 results.
# Processed Query Q0201 with 10 results.
# Processed Query Q0202 with 10 results.
# Processed Query Q0203 with 10 results.
# Processed Query Q0204 with 10 results.
# Processed Query Q0205 with 10 results.
# Processed Query Q0206 with 10 results.
# Processed Query Q0207 with 10 results.
# Processed Query Q0208 with 10 results.
# Processed Query Q0209 with 10 results.
# Processed Query Q0210 with 10 results.
# Processed Query Q0211 with 10 results.
# Processed Query Q0212 with 10 results.
# Processed Query Q0213 with 10 results.
# Processed Query Q0214 with 10 results.
# Processed Query Q0215 with 10 results.
# Processed Query Q0216 with 10 results.
# Processed Query Q0217 with 10 results.
# Processed Query Q0218 with 10 results.
# Processed Query Q0219 with 10 results.
# Processed Query Q0220 with 10 results.
# Processed Query Q0221 with 10 results.
# Processed Query Q0222 with 10 results.
# Processed Query Q0223 with 10 results.
# Processed Query Q0224 with 10 results.
# Processed Query Q0225 with 10 results.
# Processed Query Q0226 with 10 results.
# Processed Query Q0227 with 10 results.
# Processed Query Q0228 with 10 results.
# Processed Query Q0229 with 10 results.
# Processed Query Q0230 with 10 results.
# Processed Query Q0231 with 10 results.
# Processed Query Q0232 with 10 results.
# Processed Query Q0233 with 10 results.
# Processed Query Q0234 with 10 results.
# Processed Query Q0235 with 10 results.
# Processed Query Q0236 with 10 results.
# Processed Query Q0237 with 10 results.
# Processed Query Q0238 with 10 results.
# Processed Query Q0239 with 10 results.
# Processed Query Q0240 with 10 results.
# Processed Query Q0241 with 10 results.
# Processed Query Q0242 with 10 results.
# Processed Query Q0243 with 10 results.
# Processed Query Q0244 with 10 results.
# Processed Query Q0245 with 10 results.
# Processed Query Q0246 with 10 results.
# Processed Query Q0247 with 10 results.
# Processed Query Q0248 with 10 results.
# Processed Query Q0249 with 10 results.
# Processed Query Q0250 with 10 results.
# Processed Query Q0251 with 10 results.
# Processed Query Q0252 with 10 results.
# Processed Query Q0253 with 10 results.
# Processed Query Q0254 with 10 results.
# Processed Query Q0255 with 10 results.
# Processed Query Q0256 with 10 results.
# Processed Query Q0257 with 10 results.
# Processed Query Q0258 with 10 results.
# Processed Query Q0259 with 10 results.
# Processed Query Q0260 with 10 results.
# Processed Query Q0261 with 10 results.
# Processed Query Q0262 with 10 results.
# Processed Query Q0263 with 10 results.
# Processed Query Q0264 with 10 results.
# Processed Query Q0265 with 10 results.
# Processed Query Q0266 with 10 results.
# Processed Query Q0267 with 10 results.
# Processed Query Q0268 with 10 results.
# Processed Query Q0269 with 10 results.
# Processed Query Q0270 with 10 results.
# Processed Query Q0271 with 10 results.
# Processed Query Q0272 with 10 results.
# Processed Query Q0273 with 10 results.
# Processed Query Q0274 with 10 results.
# Processed Query Q0275 with 10 results.
# Processed Query Q0276 with 10 results.
# Processed Query Q0277 with 10 results.
# Processed Query Q0278 with 10 results.
# Processed Query Q0279 with 10 results.
# Processed Query Q0280 with 10 results.
# Processed Query Q0281 with 10 results.
# Processed Query Q0282 with 10 results.
# Processed Query Q0283 with 10 results.
# Processed Query Q0284 with 10 results.
# Processed Query Q0285 with 10 results.
# Processed Query Q0286 with 10 results.
# Processed Query Q0287 with 10 results.
# Processed Query Q0288 with 10 results.
# Processed Query Q0289 with 10 results.
# Processed Query Q0290 with 10 results.
# Processed Query Q0291 with 10 results.
# Processed Query Q0292 with 10 results.
# Processed Query Q0293 with 10 results.
# Processed Query Q0294 with 10 results.
# Processed Query Q0295 with 10 results.
# Processed Query Q0296 with 10 results.
# Processed Query Q0297 with 10 results.
# Processed Query Q0298 with 10 results.
# Processed Query Q0299 with 10 results.
# Processed Query Q0300 with 10 results.
# Processed Query Q0301 with 10 results.
# Processed Query Q0302 with 10 results.
# Processed Query Q0303 with 10 results.
# Processed Query Q0304 with 10 results.
# Processed Query Q0305 with 10 results.
# Processed Query Q0306 with 10 results.
# Processed Query Q0307 with 10 results.
# Processed Query Q0308 with 10 results.
# Processed Query Q0309 with 10 results.
# Processed Query Q0310 with 10 results.
# Processed Query Q0311 with 10 results.
# Processed Query Q0312 with 10 results.
# Processed Query Q0313 with 10 results.
# Processed Query Q0314 with 10 results.
# Processed Query Q0315 with 10 results.
# Processed Query Q0316 with 10 results.
# Processed Query Q0317 with 10 results.
# Processed Query Q0318 with 10 results.
# Processed Query Q0319 with 10 results.
# Processed Query Q0320 with 10 results.
# Processed Query Q0321 with 10 results.
# Processed Query Q0322 with 10 results.
# Processed Query Q0323 with 10 results.
# Processed Query Q0324 with 10 results.
# Processed Query Q0325 with 10 results.
# Processed Query Q0326 with 10 results.
# Processed Query Q0327 with 10 results.
# Processed Query Q0328 with 10 results.
# Processed Query Q0329 with 10 results.
# Processed Query Q0330 with 10 results.
# Processed Query Q0331 with 10 results.
# Processed Query Q0332 with 10 results.
# Processed Query Q0333 with 10 results.
# Processed Query Q0334 with 10 results.
# Processed Query Q0335 with 10 results.
# Processed Query Q0336 with 10 results.
# Processed Query Q0337 with 10 results.
# Processed Query Q0338 with 10 results.
# Processed Query Q0339 with 10 results.
# Processed Query Q0340 with 10 results.
# Processed Query Q0341 with 10 results.
# Processed Query Q0342 with 10 results.
# Processed Query Q0343 with 10 results.
# Processed Query Q0344 with 10 results.
# Processed Query Q0345 with 10 results.
# Processed Query Q0346 with 10 results.
# Processed Query Q0347 with 10 results.
# Processed Query Q0348 with 10 results.
# Processed Query Q0349 with 10 results.
# Processed Query Q0350 with 10 results.
# Processed Query Q0351 with 10 results.
# Processed Query Q0352 with 10 results.
# Processed Query Q0353 with 10 results.
# Processed Query Q0354 with 10 results.
# Processed Query Q0355 with 10 results.
# Processed Query Q0356 with 10 results.
# Processed Query Q0357 with 10 results.
# Processed Query Q0358 with 10 results.
# Processed Query Q0359 with 10 results.
# Processed Query Q0360 with 10 results.
# Processed Query Q0361 with 10 results.
# Processed Query Q0362 with 10 results.
# Processed Query Q0363 with 10 results.
# Processed Query Q0364 with 10 results.
# Processed Query Q0365 with 10 results.
# Processed Query Q0366 with 10 results.
# Processed Query Q0367 with 10 results.
# Processed Query Q0368 with 10 results.
# Processed Query Q0369 with 10 results.
# Processed Query Q0370 with 10 results.
# Processed Query Q0371 with 10 results.
# Processed Query Q0372 with 10 results.
# Processed Query Q0373 with 10 results.
# Processed Query Q0374 with 10 results.
# Processed Query Q0375 with 10 results.
# Processed Query Q0376 with 10 results.
# Processed Query Q0377 with 10 results.
# Processed Query Q0378 with 10 results.
# Processed Query Q0379 with 10 results.
# Processed Query Q0380 with 10 results.
# Processed Query Q0381 with 10 results.
# Processed Query Q0382 with 10 results.
# Processed Query Q0383 with 10 results.
# Processed Query Q0384 with 10 results.
# Processed Query Q0385 with 10 results.
# Processed Query Q0386 with 10 results.
# Processed Query Q0387 with 10 results.
# Processed Query Q0388 with 10 results.
# Processed Query Q0389 with 10 results.
# Processed Query Q0390 with 10 results.
# Processed Query Q0391 with 10 results.
# Processed Query Q0392 with 10 results.
# Processed Query Q0393 with 10 results.
# Processed Query Q0394 with 10 results.
# Processed Query Q0395 with 10 results.
# Processed Query Q0396 with 10 results.
# Processed Query Q0397 with 10 results.
# Processed Query Q0398 with 10 results.
# Processed Query Q0399 with 10 results.
# Processed Query Q0400 with 10 results.
# Processed Query Q0401 with 10 results.
# Processed Query Q0402 with 10 results.
# Processed Query Q0403 with 10 results.
# Processed Query Q0404 with 10 results.
# Processed Query Q0405 with 10 results.
# Processed Query Q0406 with 10 results.
# Processed Query Q0407 with 10 results.
# Processed Query Q0408 with 10 results.
# Processed Query Q0409 with 10 results.
# Processed Query Q0410 with 10 results.
# Processed Query Q0411 with 10 results.
# Processed Query Q0412 with 10 results.
# Processed Query Q0413 with 10 results.
# Processed Query Q0414 with 10 results.
# Processed Query Q0415 with 10 results.
# Processed Query Q0416 with 10 results.
# Processed Query Q0417 with 10 results.
# Processed Query Q0418 with 10 results.
# Processed Query Q0419 with 10 results.
# Processed Query Q0420 with 10 results.
# Processed Query Q0421 with 10 results.
# Processed Query Q0422 with 10 results.
# Processed Query Q0423 with 10 results.
# Processed Query Q0424 with 10 results.
# Processed Query Q0425 with 10 results.
# Processed Query Q0426 with 10 results.
# Processed Query Q0427 with 10 results.
# Processed Query Q0428 with 10 results.
# Processed Query Q0429 with 10 results.
# Processed Query Q0430 with 10 results.
# Processed Query Q0431 with 10 results.
# Processed Query Q0432 with 10 results.
# Processed Query Q0433 with 10 results.
# Processed Query Q0434 with 10 results.
# Processed Query Q0435 with 10 results.
# Processed Query Q0436 with 10 results.
# Processed Query Q0437 with 10 results.
# Processed Query Q0438 with 10 results.
# Processed Query Q0439 with 10 results.
# Processed Query Q0440 with 10 results.
# Processed Query Q0441 with 10 results.
# Processed Query Q0442 with 10 results.
# Processed Query Q0443 with 10 results.
# Processed Query Q0444 with 10 results.
# Processed Query Q0445 with 10 results.
# Processed Query Q0446 with 10 results.
# Processed Query Q0447 with 10 results.
# Processed Query Q0448 with 10 results.
# Processed Query Q0449 with 10 results.
# Processed Query Q0450 with 10 results.
# Processed Query Q0451 with 10 results.
# Processed Query Q0452 with 10 results.
# Processed Query Q0453 with 10 results.
# Processed Query Q0454 with 10 results.
# Processed Query Q0455 with 10 results.
# Processed Query Q0456 with 10 results.
# Processed Query Q0457 with 10 results.
# Processed Query Q0458 with 10 results.
# Processed Query Q0459 with 10 results.
# Processed Query Q0460 with 10 results.
# Processed Query Q0461 with 10 results.
# Processed Query Q0462 with 10 results.
# Processed Query Q0463 with 10 results.
# Processed Query Q0464 with 10 results.
# Processed Query Q0465 with 10 results.
# Processed Query Q0466 with 10 results.
# Processed Query Q0467 with 10 results.
# Processed Query Q0468 with 10 results.
# Processed Query Q0469 with 10 results.
# Processed Query Q0470 with 10 results.
# Processed Query Q0471 with 10 results.
# Processed Query Q0472 with 10 results.
# Processed Query Q0473 with 10 results.
# Processed Query Q0474 with 10 results.
# Processed Query Q0475 with 10 results.
# Processed Query Q0476 with 10 results.
# Processed Query Q0477 with 10 results.
# Processed Query Q0478 with 10 results.
# Processed Query Q0479 with 10 results.
# Processed Query Q0480 with 10 results.
# Processed Query Q0481 with 10 results.
# Processed Query Q0482 with 10 results.
# Processed Query Q0483 with 10 results.
# Processed Query Q0484 with 10 results.
# Processed Query Q0485 with 10 results.
# Processed Query Q0486 with 10 results.
# Processed Query Q0487 with 10 results.
# Processed Query Q0488 with 10 results.
# Processed Query Q0489 with 10 results.
# Processed Query Q0490 with 10 results.
# Processed Query Q0491 with 10 results.
# Processed Query Q0492 with 10 results.
# Processed Query Q0493 with 10 results.
# Processed Query Q0494 with 10 results.
# Processed Query Q0495 with 10 results.
# Processed Query Q0496 with 10 results.
# Processed Query Q0497 with 10 results.
# Processed Query Q0498 with 10 results.
# Processed Query Q0499 with 10 results.
# Processed Query Q0500 with 10 results.
# Processed Query Q0501 with 10 results.
# Processed Query Q0502 with 10 results.
# Processed Query Q0503 with 10 results.
# Processed Query Q0504 with 10 results.
# Processed Query Q0505 with 10 results.
# Processed Query Q0506 with 10 results.
# Processed Query Q0507 with 10 results.
# Processed Query Q0508 with 10 results.
# Processed Query Q0509 with 10 results.
# Processed Query Q0510 with 10 results.
# Processed Query Q0511 with 10 results.
# Processed Query Q0512 with 10 results.
# Processed Query Q0513 with 10 results.
# Processed Query Q0514 with 10 results.
# Processed Query Q0515 with 10 results.
# Processed Query Q0516 with 10 results.
# Processed Query Q0517 with 10 results.
# Processed Query Q0518 with 10 results.
# Processed Query Q0519 with 10 results.
# Processed Query Q0520 with 10 results.
# Processed Query Q0521 with 10 results.
# Processed Query Q0522 with 10 results.
# Processed Query Q0523 with 10 results.
# Processed Query Q0524 with 10 results.
# Processed Query Q0525 with 10 results.
# Processed Query Q0526 with 10 results.
# Processed Query Q0527 with 10 results.
# Processed Query Q0528 with 10 results.
# Processed Query Q0529 with 10 results.
# Processed Query Q0530 with 10 results.
# Processed Query Q0531 with 10 results.
# Processed Query Q0532 with 10 results.
# Processed Query Q0533 with 10 results.
# Processed Query Q0534 with 10 results.
# Processed Query Q0535 with 10 results.
# Processed Query Q0536 with 10 results.
# Processed Query Q0537 with 10 results.
# Processed Query Q0538 with 10 results.
# Processed Query Q0539 with 10 results.
# Processed Query Q0540 with 10 results.
# Processed Query Q0541 with 10 results.
# Processed Query Q0542 with 10 results.
# Processed Query Q0543 with 10 results.
# Processed Query Q0544 with 10 results.
# Processed Query Q0545 with 10 results.
# Processed Query Q0546 with 10 results.
# Processed Query Q0547 with 10 results.
# Processed Query Q0548 with 10 results.
# Processed Query Q0549 with 10 results.
# Processed Query Q0550 with 10 results.
# Processed Query Q0551 with 10 results.
# Processed Query Q0552 with 10 results.
# Processed Query Q0553 with 10 results.
# Processed Query Q0554 with 10 results.
# Processed Query Q0555 with 10 results.
# Processed Query Q0556 with 10 results.
# Processed Query Q0557 with 10 results.
# Processed Query Q0558 with 10 results.
# Processed Query Q0559 with 10 results.
# Processed Query Q0560 with 10 results.
# Processed Query Q0561 with 10 results.
# Processed Query Q0562 with 10 results.
# Processed Query Q0563 with 10 results.
# Processed Query Q0564 with 10 results.
# Processed Query Q0565 with 10 results.
# Processed Query Q0566 with 10 results.
# Processed Query Q0567 with 10 results.
# Processed Query Q0568 with 10 results.
# Processed Query Q0569 with 10 results.
# Processed Query Q0570 with 10 results.
# Processed Query Q0571 with 10 results.
# Processed Query Q0572 with 10 results.
# Processed Query Q0573 with 10 results.
# Processed Query Q0574 with 10 results.
# Processed Query Q0575 with 10 results.
# Processed Query Q0576 with 10 results.
# Processed Query Q0577 with 10 results.
# Processed Query Q0578 with 10 results.
# Processed Query Q0579 with 10 results.
# Processed Query Q0580 with 10 results.
# Processed Query Q0581 with 10 results.
# Processed Query Q0582 with 10 results.
# Processed Query Q0583 with 10 results.
# Processed Query Q0584 with 10 results.
# Processed Query Q0585 with 10 results.
# Processed Query Q0586 with 10 results.
# Processed Query Q0587 with 10 results.
# Processed Query Q0588 with 10 results.
# Processed Query Q0589 with 10 results.
# Processed Query Q0590 with 10 results.
# Processed Query Q0591 with 10 results.
# Processed Query Q0592 with 10 results.
# Processed Query Q0593 with 10 results.
# Processed Query Q0594 with 10 results.
# Processed Query Q0595 with 10 results.
# Processed Query Q0596 with 10 results.
# Processed Query Q0597 with 10 results.
# Processed Query Q0598 with 10 results.
# Processed Query Q0599 with 10 results.
# Processed Query Q0600 with 10 results.
# Processed Query Q0601 with 10 results.
# Processed Query Q0602 with 10 results.
# Processed Query Q0603 with 10 results.
# Processed Query Q0604 with 10 results.
# Processed Query Q0605 with 10 results.
# Processed Query Q0606 with 10 results.
# Processed Query Q0607 with 10 results.
# Processed Query Q0608 with 10 results.
# Processed Query Q0609 with 10 results.
# Processed Query Q0610 with 10 results.
# Processed Query Q0611 with 10 results.
# Processed Query Q0612 with 10 results.
# Processed Query Q0613 with 10 results.
# Processed Query Q0614 with 10 results.
# Processed Query Q0615 with 10 results.
# Processed Query Q0616 with 10 results.
# Processed Query Q0617 with 10 results.
# Processed Query Q0618 with 10 results.
# Processed Query Q0619 with 10 results.
# Processed Query Q0620 with 10 results.
# Processed Query Q0621 with 10 results.
# Processed Query Q0622 with 10 results.
# Processed Query Q0623 with 10 results.
# Processed Query Q0624 with 10 results.
# Processed Query Q0625 with 10 results.
# Processed Query Q0626 with 10 results.
# Processed Query Q0627 with 10 results.
# Processed Query Q0628 with 10 results.
# Processed Query Q0629 with 10 results.
# Processed Query Q0630 with 10 results.
# Processed Query Q0631 with 10 results.
# Processed Query Q0632 with 10 results.
# Processed Query Q0633 with 10 results.
# Processed Query Q0634 with 10 results.
# Processed Query Q0635 with 10 results.
# Processed Query Q0636 with 10 results.
# Processed Query Q0637 with 10 results.
# Processed Query Q0638 with 10 results.
# Processed Query Q0639 with 10 results.
# Processed Query Q0640 with 10 results.
# Processed Query Q0641 with 10 results.
# Processed Query Q0642 with 10 results.
# Processed Query Q0643 with 10 results.
# Processed Query Q0644 with 10 results.
# Processed Query Q0645 with 10 results.
# Processed Query Q0646 with 10 results.
# Processed Query Q0647 with 10 results.
# Processed Query Q0648 with 10 results.
# Processed Query Q0649 with 10 results.
# Processed Query Q0650 with 10 results.
# Processed Query Q0651 with 10 results.
# Processed Query Q0652 with 10 results.
# Processed Query Q0653 with 10 results.
# Processed Query Q0654 with 10 results.
# Processed Query Q0655 with 10 results.
# Processed Query Q0656 with 10 results.
# Processed Query Q0657 with 10 results.
# Processed Query Q0658 with 10 results.
# Processed Query Q0659 with 10 results.
# Processed Query Q0660 with 10 results.
# Processed Query Q0661 with 10 results.
# Processed Query Q0662 with 10 results.
# Processed Query Q0663 with 10 results.
# Processed Query Q0664 with 10 results.
# Processed Query Q0665 with 10 results.
# Processed Query Q0666 with 10 results.
# Processed Query Q0667 with 10 results.
# Processed Query Q0668 with 10 results.
# Processed Query Q0669 with 10 results.
# Processed Query Q0670 with 10 results.
# Processed Query Q0671 with 10 results.
# Processed Query Q0672 with 10 results.
# Processed Query Q0673 with 10 results.
# Processed Query Q0674 with 10 results.
# Processed Query Q0675 with 10 results.
# Processed Query Q0676 with 10 results.
# Processed Query Q0677 with 10 results.
# Processed Query Q0678 with 10 results.
# Processed Query Q0679 with 10 results.
# Processed Query Q0680 with 10 results.
# Processed Query Q0681 with 10 results.
# Processed Query Q0682 with 10 results.
# Processed Query Q0683 with 10 results.
# Processed Query Q0684 with 10 results.
# Processed Query Q0685 with 10 results.
# Processed Query Q0686 with 10 results.
# Processed Query Q0687 with 10 results.
# Processed Query Q0688 with 10 results.
# Processed Query Q0689 with 10 results.
# Processed Query Q0690 with 10 results.
# Processed Query Q0691 with 10 results.
# Processed Query Q0692 with 10 results.
# Processed Query Q0693 with 10 results.
# Processed Query Q0694 with 10 results.
# Processed Query Q0695 with 10 results.
# Processed Query Q0696 with 10 results.
# Processed Query Q0697 with 10 results.
# Processed Query Q0698 with 10 results.
# Processed Query Q0699 with 10 results.
# Processed Query Q0700 with 10 results.
# Processed Query Q0701 with 10 results.
# Processed Query Q0702 with 10 results.
# Processed Query Q0703 with 10 results.
# Processed Query Q0704 with 10 results.
# Processed Query Q0705 with 10 results.
# Processed Query Q0706 with 10 results.
# Processed Query Q0707 with 10 results.
# Processed Query Q0708 with 10 results.
# Processed Query Q0709 with 10 results.
# Processed Query Q0710 with 10 results.
# Processed Query Q0711 with 10 results.
# Processed Query Q0712 with 10 results.
# Processed Query Q0713 with 10 results.
# Processed Query Q0714 with 10 results.
# Processed Query Q0715 with 10 results.
# Processed Query Q0716 with 10 results.
# Processed Query Q0717 with 10 results.
# Processed Query Q0718 with 10 results.
# Processed Query Q0719 with 10 results.
# Processed Query Q0720 with 10 results.
# Processed Query Q0721 with 10 results.
# Processed Query Q0722 with 10 results.
# Processed Query Q0723 with 10 results.
# Processed Query Q0724 with 10 results.
# Processed Query Q0725 with 10 results.
# Processed Query Q0726 with 10 results.
# Processed Query Q0727 with 10 results.
# Processed Query Q0728 with 10 results.
# Processed Query Q0729 with 10 results.
# Processed Query Q0730 with 10 results.
# Processed Query Q0731 with 10 results.
# Processed Query Q0732 with 10 results.
# Processed Query Q0733 with 10 results.
# Processed Query Q0734 with 10 results.
# Processed Query Q0735 with 10 results.
# Processed Query Q0736 with 10 results.
# Processed Query Q0737 with 10 results.
# Processed Query Q0738 with 10 results.
# Processed Query Q0739 with 10 results.
# Processed Query Q0740 with 10 results.
# Processed Query Q0741 with 10 results.
# Processed Query Q0742 with 10 results.
# Processed Query Q0743 with 10 results.
# Processed Query Q0744 with 10 results.
# Processed Query Q0745 with 10 results.
# Processed Query Q0746 with 10 results.
# Processed Query Q0747 with 10 results.
# Processed Query Q0748 with 10 results.
# Processed Query Q0749 with 10 results.
# Processed Query Q0750 with 10 results.
# Processed Query Q0751 with 10 results.
# Processed Query Q0752 with 10 results.
# Processed Query Q0753 with 10 results.
# Processed Query Q0754 with 10 results.
# Processed Query Q0755 with 10 results.
# Processed Query Q0756 with 10 results.
# Processed Query Q0757 with 10 results.
# Processed Query Q0758 with 10 results.
# Processed Query Q0759 with 10 results.
# Processed Query Q0760 with 10 results.
# Processed Query Q0761 with 10 results.
# Processed Query Q0762 with 10 results.
# Processed Query Q0763 with 10 results.
# Processed Query Q0764 with 10 results.
# Processed Query Q0765 with 10 results.
# Processed Query Q0766 with 10 results.
# Processed Query Q0767 with 10 results.
# Processed Query Q0768 with 10 results.
# Processed Query Q0769 with 10 results.
# Processed Query Q0770 with 10 results.
# Processed Query Q0771 with 10 results.
# Processed Query Q0772 with 10 results.
# Processed Query Q0773 with 10 results.
# Processed Query Q0774 with 10 results.
# Processed Query Q0775 with 10 results.
# Processed Query Q0776 with 10 results.
# Processed Query Q0777 with 10 results.
# Processed Query Q0778 with 10 results.
# Processed Query Q0779 with 10 results.
# Processed Query Q0780 with 10 results.
# Processed Query Q0781 with 10 results.
# Processed Query Q0782 with 10 results.
# Processed Query Q0783 with 10 results.
# Processed Query Q0784 with 10 results.
# Processed Query Q0785 with 10 results.
# Processed Query Q0786 with 10 results.
# Processed Query Q0787 with 10 results.
# Processed Query Q0788 with 10 results.
# Processed Query Q0789 with 10 results.
# Processed Query Q0790 with 10 results.
# Processed Query Q0791 with 10 results.
# Processed Query Q0792 with 10 results.
# Processed Query Q0793 with 10 results.
# Processed Query Q0794 with 10 results.
# Processed Query Q0795 with 10 results.
# Processed Query Q0796 with 10 results.
# Processed Query Q0797 with 10 results.
# Processed Query Q0798 with 10 results.
# Processed Query Q0799 with 10 results.
# Processed Query Q0800 with 10 results.
# Processed Query Q0801 with 10 results.
# Processed Query Q0802 with 10 results.
# Processed Query Q0803 with 10 results.
# Processed Query Q0804 with 10 results.
# Processed Query Q0805 with 10 results.
# Processed Query Q0806 with 10 results.
# Processed Query Q0807 with 10 results.
# Processed Query Q0808 with 10 results.
# Processed Query Q0809 with 10 results.
# Processed Query Q0810 with 10 results.
# Processed Query Q0811 with 10 results.
# Processed Query Q0812 with 10 results.
# Processed Query Q0813 with 10 results.
# Processed Query Q0814 with 10 results.
# Processed Query Q0815 with 10 results.
# Processed Query Q0816 with 10 results.
# Processed Query Q0817 with 10 results.
# Processed Query Q0818 with 10 results.
# Processed Query Q0819 with 10 results.
# Processed Query Q0820 with 10 results.
# Processed Query Q0821 with 10 results.
# Processed Query Q0822 with 10 results.
# Processed Query Q0823 with 10 results.
# Processed Query Q0824 with 10 results.
# Processed Query Q0825 with 10 results.
# Processed Query Q0826 with 10 results.
# Processed Query Q0827 with 10 results.
# Processed Query Q0828 with 10 results.
# Processed Query Q0829 with 10 results.
# Processed Query Q0830 with 10 results.
# Processed Query Q0831 with 10 results.
# Processed Query Q0832 with 10 results.
# Processed Query Q0833 with 10 results.
# Processed Query Q0834 with 10 results.
# Processed Query Q0835 with 10 results.
# Processed Query Q0836 with 10 results.
# Processed Query Q0837 with 10 results.
# Processed Query Q0838 with 10 results.
# Processed Query Q0839 with 10 results.
# Processed Query Q0840 with 10 results.
# Processed Query Q0841 with 10 results.
# Processed Query Q0842 with 10 results.
# Processed Query Q0843 with 10 results.
# Processed Query Q0844 with 10 results.
# Processed Query Q0845 with 10 results.
# Processed Query Q0846 with 10 results.
# Processed Query Q0847 with 10 results.
# Processed Query Q0848 with 10 results.
# Processed Query Q0849 with 10 results.
# Processed Query Q0850 with 10 results.
# Processed Query Q0851 with 10 results.
# Processed Query Q0852 with 10 results.
# Processed Query Q0853 with 10 results.
# Processed Query Q0854 with 10 results.
# Processed Query Q0855 with 10 results.
# Processed Query Q0856 with 10 results.
# Processed Query Q0857 with 10 results.
# Processed Query Q0858 with 10 results.
# Processed Query Q0859 with 10 results.
# Processed Query Q0860 with 10 results.
# Processed Query Q0861 with 10 results.
# Processed Query Q0862 with 10 results.
# Processed Query Q0863 with 10 results.
# Processed Query Q0864 with 10 results.
# Processed Query Q0865 with 10 results.
# Processed Query Q0866 with 10 results.
# Processed Query Q0867 with 10 results.
# Processed Query Q0868 with 10 results.
# Processed Query Q0869 with 10 results.
# Processed Query Q0870 with 10 results.
# Processed Query Q0871 with 10 results.
# Processed Query Q0872 with 10 results.
# Processed Query Q0873 with 10 results.
# Processed Query Q0874 with 10 results.
# Processed Query Q0875 with 10 results.
# Processed Query Q0876 with 10 results.
# Processed Query Q0877 with 10 results.
# Processed Query Q0878 with 10 results.
# Processed Query Q0879 with 10 results.
# Processed Query Q0880 with 10 results.
# Processed Query Q0881 with 10 results.
# Processed Query Q0882 with 10 results.
# Processed Query Q0883 with 10 results.
# Processed Query Q0884 with 10 results.
# Processed Query Q0885 with 10 results.
# Processed Query Q0886 with 10 results.
# Processed Query Q0887 with 10 results.
# Processed Query Q0888 with 10 results.
# Processed Query Q0889 with 10 results.
# Processed Query Q0890 with 10 results.
# Processed Query Q0891 with 10 results.
# Processed Query Q0892 with 10 results.
# Processed Query Q0893 with 10 results.
# Processed Query Q0894 with 10 results.
# Processed Query Q0895 with 10 results.
# Processed Query Q0896 with 10 results.
# Processed Query Q0897 with 10 results.
# Processed Query Q0898 with 10 results.
# Processed Query Q0899 with 10 results.
# Processed Query Q0900 with 10 results.
# Processed Query Q0901 with 10 results.
# Processed Query Q0902 with 10 results.
# Processed Query Q0903 with 10 results.
# Processed Query Q0904 with 10 results.
# Processed Query Q0905 with 10 results.
# Processed Query Q0906 with 10 results.
# Processed Query Q0907 with 10 results.
# Processed Query Q0908 with 10 results.
# Processed Query Q0909 with 10 results.
# Processed Query Q0910 with 10 results.
# Processed Query Q0911 with 10 results.
# Processed Query Q0912 with 10 results.
# Processed Query Q0913 with 10 results.
# Processed Query Q0914 with 10 results.
# Processed Query Q0915 with 10 results.
# Processed Query Q0916 with 10 results.
# Processed Query Q0917 with 10 results.
# Processed Query Q0918 with 10 results.
# Processed Query Q0919 with 10 results.
# Processed Query Q0920 with 10 results.
# Processed Query Q0921 with 10 results.
# Processed Query Q0922 with 10 results.
# Processed Query Q0923 with 10 results.
# Processed Query Q0924 with 10 results.
# Processed Query Q0925 with 10 results.
# Processed Query Q0926 with 10 results.
# Processed Query Q0927 with 10 results.
# Processed Query Q0928 with 10 results.
# Processed Query Q0929 with 10 results.
# Processed Query Q0930 with 10 results.
# Processed Query Q0931 with 10 results.
# Processed Query Q0932 with 10 results.
# Processed Query Q0933 with 10 results.
# Processed Query Q0934 with 10 results.
# Processed Query Q0935 with 10 results.
# Processed Query Q0936 with 10 results.
# Processed Query Q0937 with 10 results.
# Processed Query Q0938 with 10 results.
# Processed Query Q0939 with 10 results.
# Processed Query Q0940 with 10 results.
# Processed Query Q0941 with 10 results.
# Processed Query Q0942 with 10 results.
# Processed Query Q0943 with 10 results.
# Processed Query Q0944 with 10 results.
# Processed Query Q0945 with 10 results.
# Processed Query Q0946 with 10 results.
# Processed Query Q0947 with 10 results.
# Processed Query Q0948 with 10 results.
# Processed Query Q0949 with 10 results.
# Processed Query Q0950 with 10 results.
# Processed Query Q0951 with 10 results.
# Processed Query Q0952 with 10 results.
# Processed Query Q0953 with 10 results.
# Processed Query Q0954 with 10 results.
# Processed Query Q0955 with 10 results.
# Processed Query Q0956 with 10 results.
# Processed Query Q0957 with 10 results.
# Processed Query Q0958 with 10 results.
# Processed Query Q0959 with 10 results.
# Processed Query Q0960 with 10 results.
# Processed Query Q0961 with 10 results.
# Processed Query Q0962 with 10 results.
# Processed Query Q0963 with 10 results.
# Processed Query Q0964 with 10 results.
# Processed Query Q0965 with 10 results.
# Processed Query Q0966 with 10 results.
# Processed Query Q0967 with 10 results.
# Processed Query Q0968 with 10 results.
# Processed Query Q0969 with 10 results.
# Processed Query Q0970 with 10 results.
# Processed Query Q0971 with 10 results.
# Processed Query Q0972 with 10 results.
# Processed Query Q0973 with 10 results.
# Processed Query Q0974 with 10 results.
# Processed Query Q0975 with 10 results.
# Processed Query Q0976 with 10 results.
# Processed Query Q0977 with 10 results.
# Processed Query Q0978 with 10 results.
# Processed Query Q0979 with 10 results.
# Processed Query Q0980 with 10 results.
# Processed Query Q0981 with 10 results.
# Processed Query Q0982 with 10 results.
# Processed Query Q0983 with 10 results.
# Processed Query Q0984 with 10 results.
# Processed Query Q0985 with 10 results.
# Processed Query Q0986 with 10 results.
# Processed Query Q0987 with 10 results.
# Processed Query Q0988 with 10 results.
# Processed Query Q0989 with 10 results.
# Processed Query Q0990 with 10 results.
# Processed Query Q0991 with 10 results.
# Processed Query Q0992 with 10 results.
# Processed Query Q0993 with 10 results.
# Processed Query Q0994 with 10 results.
# Processed Query Q0995 with 10 results.
# Processed Query Q0996 with 10 results.
# Processed Query Q0997 with 10 results.
# Processed Query Q0998 with 10 results.
# Processed Query Q0999 with 10 results.
# Processed Query Q1000 with 10 results.

# %%
print(results)
# Out:
# defaultdict(None, {'Q0001': ['NWA32554', 'NWA15911', 'NWA31765', 'NWA74717', 'NWA55684', 'NWA53358', 'NWA32132', 'NWA11263', 'NWA44914', 'NWA44937'], 'Q0002': ['NWA28648', 'NWA11425', 'NWA39137', 'NWA74695', 'NWA77695', 'NWA74515', 'NWA73716', 'NWA08916', 'NWA74704', 'NWA77275'], 'Q0003': ['NWA27852', 'NWA27863', 'NWA27835', 'NWA27823', 'NWA27831', 'NWA27828', 'NWA27830', 'NWA27829', 'NWA27824', 'NWA27827'], 'Q0004': ['NWA74708', 'NWA78594', 'NWA77305', 'NWA08650', 'NWA74760', 'NWA09761', 'NWA09222', 'NWA77695', 'NWA73614', 'NWA73707'], 'Q0005': ['NWA15368', 'NWA15503', 'NWA65193', 'NWA57504', 'NWA77333', 'NWA78428', 'NWA12430', 'NWA31907', 'NWA71523', 'NWA26257'], 'Q0006': ['NWA11425', 'NWA74843', 'NWA74894', 'NWA73716', 'NWA12143', 'NWA74515', 'NWA08916', 'NWA22037', 'NWA39137', 'NWA28648'], 'Q0007': ['NWA75577', 'NWA80268', 'NWA80281', 'NWA80275', 'NWA80276', 'NWA80274', 'NWA76584', 'NWA79781', 'NWA76199', 'NWA79764'], 'Q0008': ['NWA53603', 'NWA74718', 'NWA77305', 'NWA22883', 'NWA74695', 'NWA78594', 'NWA74726', 'NWA74844', 'NWA77306', 'NWA09289'], 'Q0009': ['NWA80269', 'NWA09200', 'NWA80275', 'NWA80281', 'NWA75605', 'NWA73618', 'NWA80268', 'NWA67191', 'NWA39045', 'NWA70520'], 'Q0010': ['NWA78428', 'NWA73909', 'NWA65193', 'NWA78594', 'NWA16411', 'NWA74500', 'NWA10555', 'NWA73707', 'NWA40400', 'NWA77980'], 'Q0011': ['NWA73670', 'NWA78372', 'NWA77306', 'NWA39459', 'NWA03579', 'NWA03890', 'NWA02798', 'NWA07199', 'NWA50810', 'NWA06111'], 'Q0012': ['NWA75577', 'NWA80268', 'NWA80275', 'NWA80281', 'NWA76584', 'NWA80276', 'NWA76199', 'NWA80274', 'NWA80269', 'NWA75615'], 'Q0013': ['NWA74843', 'NWA75834', 'NWA23337', 'NWA74708', 'NWA74844', 'NWA13136', 'NWA73662', 'NWA74822', 'NWA74760', 'NWA15870'], 'Q0014': ['NWA77020', 'NWA65193', 'NWA71523', 'NWA57504', 'NWA74195', 'NWA15368', 'NWA34233', 'NWA78428', 'NWA15503', 'NWA32132'], 'Q0015': ['NWA75611', 'NWA80281', 'NWA80268', 'NWA79775', 'NWA76199', 'NWA80276', 'NWA37107', 'NWA80275', 'NWA39665', 'NWA79778'], 'Q0016': ['NWA30167', 'NWA29655', 'NWA29511', 'NWA29846', 'NWA29389', 'NWA29178', 'NWA29278', 'NWA29156', 'NWA29122', 'NWA29144'], 'Q0017': ['NWA80276', 'NWA75591', 'NWA80260', 'NWA80264', 'NWA80265', 'NWA75589', 'NWA80258', 'NWA80262', 'NWA80266', 'NWA80261'], 'Q0018': ['NWA11425', 'NWA28648', 'NWA39137', 'NWA77695', 'NWA77275', 'NWA74515', 'NWA08916', 'NWA74695', 'NWA74704', 'NWA22883'], 'Q0019': ['NWA12776', 'NWA74760', 'NWA09222', 'NWA21925', 'NWA09971', 'NWA09849', 'NWA09233', 'NWA33930', 'NWA09982', 'NWA15342'], 'Q0020': ['NWA46583', 'NWA75930', 'NWA73811', 'NWA73791', 'NWA73792', 'NWA73788', 'NWA74904', 'NWA73810', 'NWA75013', 'NWA73812'], 'Q0021': ['NWA73535', 'NWA73539', 'NWA74843', 'NWA46958', 'NWA74860', 'NWA77695', 'NWA77196', 'NWA73538', 'NWA09607', 'NWA74822'], 'Q0022': ['NWA74760', 'NWA33805', 'NWA33803', 'NWA33810', 'NWA11779', 'NWA80268', 'NWA13404', 'NWA33807', 'NWA11263', 'NWA09222'], 'Q0023': ['NWA74697', 'NWA57353', 'NWA74708', 'NWA50848', 'NWA73714', 'NWA11263', 'NWA78261', 'NWA74843', 'NWA10289', 'NWA52385'], 'Q0024': ['NWA43524', 'NWA13404', 'NWA74843', 'NWA12165', 'NWA16411', 'NWA74704', 'NWA74718', 'NWA78594', 'NWA73707', 'NWA09563'], 'Q0025': ['NWA77895', 'NWA74717', 'NWA77306', 'NWA74843', 'NWA11263', 'NWA39034', 'NWA73662', 'NWA11425', 'NWA77995', 'NWA77185'], 'Q0026': ['NWA77895', 'NWA77532', 'NWA39034', 'NWA77306', 'NWA29990', 'NWA74717', 'NWA73907', 'NWA77695', 'NWA21925', 'NWA77310'], 'Q0027': ['NWA77532', 'NWA13404', 'NWA77895', 'NWA80275', 'NWA09222', 'NWA80268', 'NWA28648', 'NWA69965', 'NWA11263', 'NWA73707'], 'Q0028': ['NWA76181', 'NWA74907', 'NWA75913', 'NWA49333', 'NWA80235', 'NWA75644', 'NWA80241', 'NWA75628', 'NWA75627', 'NWA75626'], 'Q0029': ['NWA09222', 'NWA28648', 'NWA77310', 'NWA11425', 'NWA78594', 'NWA39137', 'NWA17665', 'NWA77275', 'NWA50848', 'NWA46958'], 'Q0030': ['NWA79767', 'NWA73909', 'NWA48179', 'NWA44903', 'NWA78628', 'NWA73912', 'NWA79907', 'NWA76175', 'NWA56133', 'NWA09168'], 'Q0031': ['NWA25951', 'NWA50848', 'NWA42349', 'NWA4 ...

# %%
# saving the run in a json file
import json

outputfile = "data/muril.json"

with open(outputfile, 'w', encoding='utf-8') as f:
    json.dump(results,
              f,
              indent=4,
              ensure_ascii=False
             )

# %% [markdown]
# # Calculating the Top@1 accuray, Top@5 accuracy and Mean Average Precision

# %%
import pandas as pd
from collections import defaultdict

ground_truth = pd.read_csv('data/groundtruth.csv')
file_path = "data/tfidf.json"

with open(file_path, 'r') as file_handle:
    # 2. Use json.load() (without the 's') to convert the file content to a dict
    predictions = json.load(file_handle)
    
# Build ground truth dictionary
gt_dict = {}
for _, row in ground_truth.iterrows():
    gt_dict[row['QueryID']] = row['relevant docs']

# Calculate metrics
def calculate_metrics(predictions, ground_truth, k_values=[1, 5]):
    results = {f'top{k}': [] for k in k_values}
    ap_scores = []
    
    for query_id, ranked_docs in predictions.items():
        relevant_doc = ground_truth.get(query_id)
        
        if relevant_doc is None:
            continue
            
        # Top-k accuracy
        for k in k_values:
            top_k_docs = ranked_docs[:k]
            results[f'top{k}'].append(1 if relevant_doc in top_k_docs else 0)
        
        # Average Precision
        if relevant_doc in ranked_docs:
            position = ranked_docs.index(relevant_doc) + 1  # 1-indexed
            ap = 1.0 / position
        else:
            ap = 0.0
        ap_scores.append(ap)
    
    # Calculate averages
    metrics = {}
    for k in k_values:
        metrics[f'Top-{k} Accuracy'] = sum(results[f'top{k}']) / len(results[f'top{k}'])
    metrics['MAP'] = sum(ap_scores) / len(ap_scores)
    
    return metrics

# Calculate and print results
metrics = calculate_metrics(predictions, gt_dict)

print("Evaluation Metrics:")
print("-" * 40)
for metric_name, score in metrics.items():
    print(f"{metric_name}: {score:.4f} ({score*100:.2f}%)")
# Out:
# Evaluation Metrics:
# ----------------------------------------
# Top-1 Accuracy: 0.7230 (72.30%)
# Top-5 Accuracy: 0.8860 (88.60%)
# MAP: 0.7948 (79.48%)

# %%
import pandas as pd
from collections import defaultdict

ground_truth = pd.read_csv('data/groundtruth.csv')
file_path = "data/muril.json"

with open(file_path, 'r') as file_handle:
    # 2. Use json.load() (without the 's') to convert the file content to a dict
    predictions = json.load(file_handle)
    
# Build ground truth dictionary
gt_dict = {}
for _, row in ground_truth.iterrows():
    gt_dict[row['QueryID']] = row['relevant docs']

# Calculate metrics
def calculate_metrics(predictions, ground_truth, k_values=[1, 5]):
    results = {f'top{k}': [] for k in k_values}
    ap_scores = []
    
    for query_id, ranked_docs in predictions.items():
        relevant_doc = ground_truth.get(query_id)
        
        if relevant_doc is None:
            continue
            
        # Top-k accuracy
        for k in k_values:
            top_k_docs = ranked_docs[:k]
            results[f'top{k}'].append(1 if relevant_doc in top_k_docs else 0)
        
        # Average Precision
        if relevant_doc in ranked_docs:
            position = ranked_docs.index(relevant_doc) + 1  # 1-indexed
            ap = 1.0 / position
        else:
            ap = 0.0
        ap_scores.append(ap)
    
    # Calculate averages
    metrics = {}
    for k in k_values:
        metrics[f'Top-{k} Accuracy'] = sum(results[f'top{k}']) / len(results[f'top{k}'])
    metrics['MAP'] = sum(ap_scores) / len(ap_scores)
    
    return metrics

# Calculate and print results
metrics = calculate_metrics(predictions, gt_dict)

print("Evaluation Metrics:")
print("-" * 40)
for metric_name, score in metrics.items():
    print(f"{metric_name}: {score:.4f} ({score*100:.2f}%)")
# Out:
# Evaluation Metrics:
# ----------------------------------------
# Top-1 Accuracy: 0.0120 (1.20%)
# Top-5 Accuracy: 0.0260 (2.60%)
# MAP: 0.0186 (1.86%)
